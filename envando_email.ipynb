# %%
import pyautogui
import pyperclip
import time
pyautogui.PAUSE = 1
# abrindo o google acessando o google drive onde se encontra um rquivo de excel e fazendo o dawnload
pyautogui.press("win")
pyautogui.write("chome")
pyautogui.press("enter")
time.sleep(7)
pyautogui.hotkey("ctrl","t")
pyautogui.write("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga")
pyautogui.press("enter")
time.sleep(10)
pyautogui.click(x=1723, y=335, clicks=2)
time.sleep(4)
pyautogui.click(x=1727, y=421)
time.sleep(4)
pyautogui.click(x=2772, y=141)
time.sleep(3)
pyautogui.click(x=2506, y=580)

# %%
# abrindo o arquivo em excel e analisando somando o faturamento e a quantidade
import pandas as pd
tabela = pd.read_excel(r"C:\Users\amatt\Downloads\Vendas - Dez.xlsx")
display(tabela)
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# logo apos fazer a analise da tabela em excel enviamos um email com os resultados para o remetente de sua escolha
pyautogui.press("win")
pyautogui.write("chome")
pyautogui.press("enter")
time.sleep(3)
pyautogui.write("https://mail.google.com/mail/u/0/#inbox")
pyautogui.press("enter")
time.sleep(9)
pyautogui.click(x=1451, y=156)
time.sleep(8)
pyautogui.write("amattiprf@gmail.com")
pyautogui.press("tab")
time.sleep(4)
pyautogui.press("tab")
pyautogui.write("Relatorio de vendas")
time.sleep(4)

pyautogui.press("tab")
time.sleep(4)

texto = f"""prezados, bom dia
o faturamento foi de : {faturamento: ,.2f}
a quantidade de vendas foi de: {quantidade: ,}
abraço!
jackson amatti"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")
time.sleep(2)
pyautogui.hotkey("tab","enter")

# %%
time.sleep(9)
pyautogui.position() #achar posicao onde clicar
# Out:
# Point(x=1266, y=385)
